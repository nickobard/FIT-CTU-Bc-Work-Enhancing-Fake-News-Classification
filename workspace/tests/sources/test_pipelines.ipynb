# %%
from workspace.sources.local_datasets.preprocessing.cleaning import NoiseReduction
from workspace.sources.local_datasets.preprocessing.encoders.bert_base_uncased import BertBaseUncasedEncoder
from workspace.sources.experiments.metrics import Loss
from workspace.sources.experiments.experiment import Experiment
from workspace.sources.local_datasets.dataset import Dataset
from workspace.sources.local_datasets.preprocessing.pipelines import PreprocessingPipeline
from workspace.sources.local_datasets.preprocessing.transformations import Truncation
from workspace.sources.models.transformers.bert.bert_base_uncased import BertBaseUncased
import mlflow

mlflow.set_tracking_uri('../../mlruns')

# %%
preprocessings = PreprocessingPipeline(name='truncated_cleaned_bert_pipeline',
                                       iterable=[Truncation(0.1), NoiseReduction(), BertBaseUncasedEncoder()])
dataset = Dataset('ReCovery', '../../sources/local_datasets/data/ReCOVery/recovery.csv', preprocessings)

model_training_arguments = {'epochs': 5,
                            'early_stopping_patience': 3,
                            'early_stopping_threshold': 0.001}

model = BertBaseUncased(train_best_model_metric=Loss,
                        training_arguments=model_training_arguments)

recovery_experiment = Experiment(
    name='testing-pipelines-bert-base-uncased',
    run_id=None,
    dataset=dataset,
    model=model)
recovery_experiment.run()
# Out:
# 2025/05/13 18:23:08 INFO mlflow.tracking.fluent: Experiment with name 'testing-pipelines-bert-base-uncased' does not exist. Creating a new experiment.
# 2025-05-13 18:23:08,200 - Experiment - INFO - MLflow experiment initialized with ID: 561272604917995285
# 2025-05-13 18:23:08,452 - Experiment - INFO - Run ID: 0b40100af1a043d9b6f20bd47e4d3526
# 2025-05-13 18:23:08,452 - Experiment - INFO - Run name: glamorous-squid-2
# 2025-05-13 18:23:08,481 - Experiment - INFO - Prepared dataset does not exist, computing from scratch.
# ...
