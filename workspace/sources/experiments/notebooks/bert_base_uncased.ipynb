# %%
from sources.experiments.experiment import Experiment
from sources.local_datasets.dataset import Dataset
from sources.models.bert_base_uncased import BertBaseUncased
from sources.local_datasets.preprocessing.utils import minimal_bert_pipeline
import mlflow
mlflow.set_tracking_uri('../../../mlruns')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sources.experiments.experiment import Experiment
#       2 from sources.local_datasets.dataset import Dataset
#       3 from sources.models.bert_base_uncased import BertBaseUncased
#
# ModuleNotFoundError: No module named 'sources'

# %% [markdown]
# ### ReCovery Dataset

# %%
preprocessings = minimal_bert_pipeline
dataset = Dataset('ReCovery', '../../local_datasets/data/Recovery/recovery.csv', preprocessings)
model = BertBaseUncased()
recovery_experiment = Experiment(
    name='bert base uncased - testing',
    run_id='28f7141b79834c4aa57b99e0819f227f',
    dataset=dataset,
    model=model)
recovery_experiment.run()
# Out:
# 2025-05-08 21:04:55,031 - Experiment - INFO - MLflow experiment initialized with ID: 206496448065585351
# INFO:Experiment:MLflow experiment initialized with ID: 206496448065585351
# 2025-05-08 21:04:55,156 - Experiment - INFO - Run ID: 28f7141b79834c4aa57b99e0819f227f
# INFO:Experiment:Run ID: 28f7141b79834c4aa57b99e0819f227f
# 2025-05-08 21:04:55,158 - Experiment - INFO - Run name: gifted-gull-600
# INFO:Experiment:Run name: gifted-gull-600
# 2025-05-08 21:04:55,162 - Experiment - INFO - Prepared dataset exists, trying to load it.
# INFO:Experiment:Prepared dataset exists, trying to load it.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
# ...

# %% [markdown]
# ### EUVSDISINFO

# %% [markdown]
# ### ISOT

# %% [markdown]
# ### Recovery

# %% [markdown]
# ### CZ Dataset
