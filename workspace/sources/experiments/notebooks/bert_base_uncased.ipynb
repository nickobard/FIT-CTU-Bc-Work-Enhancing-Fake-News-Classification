# %%
from workspace.sources.experiments.experiment import Experiment
from workspace.sources.datasets.dataset import Dataset
from workspace.sources.datasets.preprocessing.utils import minimal_bert_pipeline
from workspace.sources.models.bert_base_uncased import BertBaseUncased

import mlflow
mlflow.set_tracking_uri('../../../mlruns')

# %% [markdown]
# ### ReCovery Dataset

# %%
preprocessings = minimal_bert_pipeline
dataset = Dataset('ReCovery', '../../datasets/data/Recovery/recovery.csv', preprocessings)
model = BertBaseUncased()
recovery_experiment = Experiment(
    name='test-bert-base-uncased',
    run_id='9102d8b81898436dabd1718e4152d603',
    dataset=dataset,
    model=model)
recovery_experiment.run()
# Out:
# 2025-05-09 12:54:37,002 - Experiment - INFO - MLflow experiment initialized with ID: 973562548005385957
# 2025-05-09 12:54:37,034 - Experiment - INFO - Run ID: 9102d8b81898436dabd1718e4152d603
# 2025-05-09 12:54:37,035 - Experiment - INFO - Run name: valuable-snail-184
# 2025-05-09 12:54:37,042 - Experiment - WARNING - Changing param values is not allowed. Param with key='preprocessing_pipeline_representation' was already logged with value='<PreprocessingPipeline 'minima_bert_pipeline': [<workspace.sources.datasets.preprocessing.tokenization.BertBaseUncasedTokenizer object at 0x000001C0AC708980>, <workspace.sources.datasets.preprocessing.encoding.BertBaseUncasedEncoder object at 0x000001C0B8A9CC50>, <workspace.sources.datasets.preprocessing.encoding.HuggingFaceDatasetConversion object at 0x000001C0B8A9CBF0>]>' for run ID='9102d8b81898436dabd1718e4152d603'. Attempted logging new value '<PreprocessingPipeline 'minima_bert_pipeline': [<workspace.sources.datasets.preprocessing.tokenization.BertBaseUncasedTokenizer object at 0x0000024A2A583470>, <workspace.sources.datasets.preprocessing.encoding.BertBaseUncasedEncoder object at 0x0000024A37C02C90>, <workspace.sources.datasets.preprocessing.encoding.HuggingFaceDatasetConversion object at 0x0000024A376482F0>]>'.
# 2025-05-09 12:54:37,052 - Experiment - INFO - Prepared dataset does not exist, computing from scratch.
# 2025-05-09 12:54:37,218 - Experiment - INFO - Initializing preprocessing pipeline: <PreprocessingPipeline 'minima_bert_pipeline': [<workspace.sources.datasets.preprocessing.tokenization.BertBaseUncasedTokenizer object at 0x0000024A2A583470>, <workspace.sources.datasets.preprocessing.encoding.BertBaseUncasedEncoder object at 0x0000024A37C02C90>, <workspace.sources.datasets.preprocessing.encoding.HuggingFaceDatasetConversion object at 0x0000024A376482F0>]>
# 2025-05-09 12:54:37,769 - Experiment - INFO - Preprocessing function 0: bert_base_uncased_tokenizer
# 2025-05-09 12:54:37,769 - Experiment - INFO - Preprocessing split: train_set
# 2025-05-09 12:54:37,771 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:37,942 - Experiment - INFO - Preprocessing split: val_set
# 2025-05-09 12:54:37,943 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:37,977 - Experiment - INFO - Preprocessing split: test_set
# 2025-05-09 12:54:37,978 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:38,194 - Experiment - INFO - Preprocessing function 1: bert_base_uncased_encoder
# 2025-05-09 12:54:38,194 - Experiment - INFO - Preprocessing split: train_set
# 2025-05-09 12:54:38,194 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:38,242 - Experiment - INFO - Preprocessing split: val_set
# 2025-05-09 12:54:38,274 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:38,274 - Experiment - INFO - Preprocessing split: test_set
# 2025-05-09 12:54:38,294 - Experiment - INFO - Preprocessed data exists, loading it.
# 2025-05-09 12:54:38,305 - Experiment - INFO - Preprocessing function 2: hugging_face_dataset_conversion
# 2025-05-09 12:54:38,305 - Experiment - INFO - Preprocessing split: train_set
# 2025-05-09 12:54:38,312 - Experiment - INFO - Preprocessed data does not exist, computing from scratch.
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\datasets\__init__.py
# Creating CSV from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# 2025-05-09 12:54:42,532 - Experiment - INFO - Preprocessing split: val_set
# 2025-05-09 12:54:42,554 - Experiment - INFO - Preprocessed data does not exist, computing from scratch.
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\datasets\__init__.py
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 2025-05-09 12:54:43,509 - Experiment - INFO - Preprocessing split: test_set
# 2025-05-09 12:54:43,518 - Experiment - INFO - Preprocessed data does not exist, computing from scratch.
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\datasets\__init__.py
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='534' max='534' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [534/534 10:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>False Positive Rate</th>
#       <th>False Negative Rate</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.656300</td>
#       <td>0.629112</td>
#       <td>0.945032</td>
#       <td>0.004224</td>
#       <td>0.682394</td>
#       <td>0.678417</td>
#       <td>0.995776</td>
#       <td>0.807018</td>
#       <td>0.638820</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.656200</td>
#       <td>0.605576</td>
#       <td>0.947146</td>
#       <td>0.000000</td>
#       <td>0.684507</td>
#       <td>0.678853</td>
#       <td>1.000000</td>
#       <td>0.808711</td>
#       <td>0.771417</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.464000</td>
#       <td>0.388892</td>
#       <td>0.331924</td>
#       <td>0.073918</td>
#       <td>0.840141</td>
#       <td>0.848162</td>
#       <td>0.926082</td>
#       <td>0.885411</td>
#       <td>0.886695</td>
#     </tr>
#   </tbody>
# </table><p>
# 2025-05-09 13:05:22,249 - Experiment - INFO - Saving evaluation data in pickle...
# 2025-05-09 13:05:22,252 - Experiment - INFO - Saving evaluation data in json...
# 2025-05-09 13:05:22,261 - Experiment - INFO - Successfully saved evaluation data.

# %% [markdown]
# ### EUVSDISINFO

# %% [markdown]
# ### ISOT

# %% [markdown]
# ### Recovery

# %% [markdown]
# ### CZ Dataset
