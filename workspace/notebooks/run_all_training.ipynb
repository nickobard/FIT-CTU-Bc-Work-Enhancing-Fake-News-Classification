# %%
# %cd bert_base_uncased
# %run training.ipynb
# Out:
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\bert_base_uncased
# Experiment: bert
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# WARNING:root:Malformed experiment 'tmp'. Detailed error Yaml file '..\..\mlruns\tmp\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %cd ../distillibert
# %run training.ipynb
# Out:
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\distillibert
# Experiment: distillibert
# Dataset Hyperparameters Grid Size:  8
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  8
# ### Run 1 of 8
# WARNING:root:Malformed experiment 'tmp'. Detailed error Yaml file '..\..\mlruns\tmp\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %cd ../roberta
# %run training.ipynb
# Out:
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\roberta
# Experiment: roberta
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# WARNING:root:Malformed experiment 'tmp'. Detailed error Yaml file '..\..\mlruns\tmp\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\.venv\Lib\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %cd ../openai_gpt1
# %run training.ipynb

# %%
# %cd ../openai_gpt2
# %run training.ipynb
