# %%
total_notebooks_to_train = ['bert_base_uncased', 'distillibert', 'roberta', 'openai_gpt1', 'openai_gpt2']
already_trained = ['bert_base_uncased', 'distillibert', 'roberta', 'openai_gpt2']
to_train = ['openai_gpt1']

# %%
for notebook in to_train:
    print(f'Training {notebook} notebook')
    # %cd $notebook
    # %run training.ipynb
    # %cd ..
