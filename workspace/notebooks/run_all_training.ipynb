# %%
notebooks_to_train = ['bert_base_uncased', 'distillibert', 'roberta', 'openai_gpt1', 'openai_gpt2']
already_trained = ['bert_base_uncased', 'distillibert', 'roberta']

# %%
for notebook in notebooks_to_train:
    if notebook in already_trained:
        print(f'Notebook {notebook} already trained')
        continue
    print(f'Training {notebook} notebook')
    # %cd $notebook
    # %run training.ipynb
    # %cd ..
# Out:
# Notebook bert_base_uncased already trained
# Notebook distillibert already trained
# Training roberta notebook
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\roberta
# Experiment: roberta
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# 2025-05-16 19:21:06,816 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:06,816 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:06,816 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:06,816 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:07,748 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:07,749 - Experiment - INFO - Existing run ID: aaf2c9e6f3ee49d18eaeecb0e850314d
# 2025-05-16 19:21:07,750 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:07,757 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:07,758 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:07,759 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:07,760 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:08,680 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:08,680 - Experiment - INFO - Existing run ID: aaf2c9e6f3ee49d18eaeecb0e850314d
# 2025-05-16 19:21:08,799 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:08,800 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 2 of 4
# 2025-05-16 19:21:08,811 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:08,812 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:08,812 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:08,813 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:09,745 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:09,746 - Experiment - INFO - Existing run ID: 2507c8e0dd2e48848b36d08e138c5e40
# 2025-05-16 19:21:09,747 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:09,755 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:09,756 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:09,756 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:09,756 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:10,699 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:10,699 - Experiment - INFO - Existing run ID: 2507c8e0dd2e48848b36d08e138c5e40
# 2025-05-16 19:21:10,832 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:10,833 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 3 of 4
# 2025-05-16 19:21:10,845 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:10,846 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:10,846 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:10,847 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:11,807 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:11,808 - Experiment - INFO - Existing run ID: 8a5f86028655451db42984f470c0991f
# 2025-05-16 19:21:11,808 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:11,816 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:11,816 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:11,816 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:11,816 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:12,712 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:12,713 - Experiment - INFO - Existing run ID: 8a5f86028655451db42984f470c0991f
# 2025-05-16 19:21:12,833 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:12,833 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 4 of 4
# 2025-05-16 19:21:12,852 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:12,853 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:12,853 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:12,854 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:13,762 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:13,763 - Experiment - INFO - Existing run ID: 1580c4ee4288452ab23b6574470dcd3b
# 2025-05-16 19:21:13,763 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:13,765 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:13,765 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:13,765 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:13,765 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:14,683 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:14,683 - Experiment - INFO - Existing run ID: 1580c4ee4288452ab23b6574470dcd3b
# 2025-05-16 19:21:14,799 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:14,799 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 1 of 4
# 2025-05-16 19:21:14,816 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:14,816 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:14,816 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:14,816 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:15,765 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:15,765 - Experiment - INFO - Existing run ID: 734b985d331b479f9cf8021e86a9a2bc
# 2025-05-16 19:21:15,765 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:15,781 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:15,781 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:15,782 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:15,783 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:16,699 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:16,715 - Experiment - INFO - Existing run ID: 734b985d331b479f9cf8021e86a9a2bc
# 2025-05-16 19:21:16,839 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:16,840 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 2 of 4
# 2025-05-16 19:21:16,852 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:16,853 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:16,854 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:16,854 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:17,816 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:17,816 - Experiment - INFO - Existing run ID: ecd31e309eaa4360b7ecd5f799b2bba2
# 2025-05-16 19:21:17,816 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:17,833 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:17,834 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:17,835 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:17,836 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:18,765 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:18,765 - Experiment - INFO - Existing run ID: ecd31e309eaa4360b7ecd5f799b2bba2
# 2025-05-16 19:21:18,883 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:18,883 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 3 of 4
# 2025-05-16 19:21:18,902 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:18,903 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:18,904 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:18,905 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:19,866 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:19,866 - Experiment - INFO - Existing run ID: bd31d523e17f4b68bb162092483d93ad
# 2025-05-16 19:21:19,866 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:19,866 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:19,866 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:19,866 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:19,866 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:20,800 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:20,800 - Experiment - INFO - Existing run ID: bd31d523e17f4b68bb162092483d93ad
# 2025-05-16 19:21:20,916 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:20,916 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 4 of 4
# 2025-05-16 19:21:20,933 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:20,933 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:20,933 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:20,933 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:21,883 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:21,883 - Experiment - INFO - Existing run ID: 712d8709104e45d1ad6ae1da1721540d
# 2025-05-16 19:21:21,883 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:21,883 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:21,883 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:21,883 - Experiment - INFO - Dataset signature: dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:21,883 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:22,840 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=euvsdisinfo,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:22,841 - Experiment - INFO - Existing run ID: 712d8709104e45d1ad6ae1da1721540d
# 2025-05-16 19:21:22,965 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:22,966 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 1 of 4
# 2025-05-16 19:21:22,966 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:22,966 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:22,966 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:22,966 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:23,900 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:23,900 - Experiment - INFO - Existing run ID: e6ecbe7f507240ad88cd001fc47ab2cc
# 2025-05-16 19:21:23,900 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:23,900 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:23,900 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:23,900 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:23,900 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:24,816 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:24,816 - Experiment - INFO - Existing run ID: e6ecbe7f507240ad88cd001fc47ab2cc
# 2025-05-16 19:21:24,956 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:24,957 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 2 of 4
# 2025-05-16 19:21:24,968 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:24,970 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:24,970 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:24,971 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:25,917 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:25,917 - Experiment - INFO - Existing run ID: 0b420f228dfe4585b4f7b9353b90c4da
# 2025-05-16 19:21:25,917 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:25,933 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:25,933 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:25,933 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:25,933 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:26,871 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:26,871 - Experiment - INFO - Existing run ID: 0b420f228dfe4585b4f7b9353b90c4da
# 2025-05-16 19:21:27,007 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:27,008 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 3 of 4
# 2025-05-16 19:21:27,017 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:27,017 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:27,017 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:27,017 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:28,006 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:28,006 - Experiment - INFO - Existing run ID: bcdf1a56d4ff42d580f8b83ecfa26ab1
# 2025-05-16 19:21:28,007 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:28,014 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:28,016 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:28,017 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:28,017 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:28,917 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),lemmatization(lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:28,917 - Experiment - INFO - Existing run ID: bcdf1a56d4ff42d580f8b83ecfa26ab1
# 2025-05-16 19:21:29,056 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:29,058 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 4 of 4
# 2025-05-16 19:21:29,066 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:29,066 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:29,066 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:29,066 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:30,038 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:30,039 - Experiment - INFO - Existing run ID: 66b6b34b24104ba2ba26b9aebe624d67
# 2025-05-16 19:21:30,039 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:30,047 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:30,047 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:30,048 - Experiment - INFO - Dataset signature: dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:30,050 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:30,976 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=isot,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=en),stemming(st=snowball,lc=en),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:30,976 - Experiment - INFO - Existing run ID: 66b6b34b24104ba2ba26b9aebe624d67
# 2025-05-16 19:21:31,121 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:31,122 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# 2025-05-16 19:21:31,133 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:31,133 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:31,133 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:31,133 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:32,134 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:32,134 - Experiment - INFO - Existing run ID: 1e0aaf6a3dee4d048d813339abb37cdd
# 2025-05-16 19:21:32,134 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:32,152 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:32,153 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:32,153 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:32,154 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:33,077 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:33,077 - Experiment - INFO - Existing run ID: 1e0aaf6a3dee4d048d813339abb37cdd
# 2025-05-16 19:21:33,200 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:33,200 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 2 of 4
# 2025-05-16 19:21:33,200 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:33,216 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:33,217 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:33,217 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:34,178 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:34,179 - Experiment - INFO - Existing run ID: 4993de6ac1e04ff980bc16b392074770
# 2025-05-16 19:21:34,180 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:34,183 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:34,183 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:34,183 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:34,183 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:35,083 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# 2025-05-16 19:21:35,083 - Experiment - INFO - Existing run ID: 4993de6ac1e04ff980bc16b392074770
# 2025-05-16 19:21:35,200 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:35,200 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 3 of 4
# 2025-05-16 19:21:35,226 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:35,226 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:35,226 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:35,226 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:36,177 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:36,177 - Experiment - INFO - Existing run ID: 8389ac7092854d21babe0cc6ae9e8d66
# 2025-05-16 19:21:36,178 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:36,183 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:36,183 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:36,183 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:36,183 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:37,100 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),lemmatization(lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:37,100 - Experiment - INFO - Existing run ID: 8389ac7092854d21babe0cc6ae9e8d66
# 2025-05-16 19:21:37,235 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:37,236 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# ### Run 4 of 4
# 2025-05-16 19:21:37,246 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:37,247 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:37,248 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:37,249 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:38,184 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:38,184 - Experiment - INFO - Existing run ID: 886a5038be7b4914b1a405b4a9ced79e
# 2025-05-16 19:21:38,184 - Experiment - INFO - Skipping current experiment run, because run with same signature already exists.
# 2025-05-16 19:21:38,200 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:21:38,200 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:21:38,200 - Experiment - INFO - Dataset signature: dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:38,200 - Experiment - INFO - Run signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:39,134 - Experiment - INFO - Found existing run with signature model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01);dataset(dn=cz_dataset,tp=0.7,vp=0.15);pipeline([noise_reduction(),nltk_tokenizer(lc=cs),stemming(st=czech_stemmer,lc=cs),ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=true)])
# 2025-05-16 19:21:39,134 - Experiment - INFO - Existing run ID: 886a5038be7b4914b1a405b4a9ced79e
# 2025-05-16 19:21:39,265 - Experiment - INFO - Pruning models artifacts to free space...
# 2025-05-16 19:21:39,267 - Experiment - INFO - Model artifacts path does not exist. Could not prune artifacts...
# UsageError: Line magic function `%cd..` not found.
