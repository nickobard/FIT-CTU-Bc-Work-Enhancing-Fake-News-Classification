# %%
notebooks_to_train = ['bert_base_uncased', 'distillibert', 'roberta', 'openai_gpt1', 'openai_gpt2']
already_trained = ['bert_base_uncased', 'distillibert', 'roberta']

# %%
for notebook in notebooks_to_train:
    if notebook in already_trained:
        print(f'Notebook {notebook} already trained')
        continue
    print(f'Training {notebook} notebook')
    # %cd $notebook
    # %run training.ipynb
    # %cd ..
# Out:
# Notebook bert_base_uncased already trained
# Notebook distillibert already trained
# Notebook roberta already trained
# Training openai_gpt1 notebook
# [WinError 2] The system cannot find the file specified: 'openai_gpt1'
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\roberta
# Experiment: roberta
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# 2025-05-16 19:26:43,300 - Experiment - INFO - MLflow experiment initialized with ID: 217717477222705143
# 2025-05-16 19:26:43,304 - Experiment - INFO - Model signature: model(mn=roberta,ti=roberta-base,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 19:26:43,304 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([ro_ber_ta_encoder(t=roberta-base,t=true,p=max_length,tml=128,isiw=false)])
# ...
