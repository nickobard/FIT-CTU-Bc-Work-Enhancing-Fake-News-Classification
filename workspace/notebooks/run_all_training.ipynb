# %%
# %cd bert_base_uncased
# %run training.ipynb
# Out:
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\bert_base_uncased
# Experiment: bert
# Dataset Hyperparameters Grid Size:  4
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  4
# ### Run 1 of 4
# 2025-05-16 12:04:33,500 - Experiment - INFO - MLflow experiment initialized with ID: 852930392549225895
# 2025-05-16 12:04:33,501 - Experiment - INFO - Model signature: model(mn=bert,ti=bert-base-uncased,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 12:04:33,502 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([bert_base_uncased_encoder(t=bert-base-uncased,t=true,p=max_length,tml=128,isiw=false)])
# ...

# %%
# %cd ../distillibert
# %run training.ipynb
# Out:
# C:\Users\nikita.bardatskii\git\bi-bap-2025-bardanik\workspace\notebooks\distillibert
# Experiment: distillibert
# Dataset Hyperparameters Grid Size:  8
# Model Hyperparameters Grid Size:  1
# Total Hyperparameter Combinations:  8
# ### Run 1 of 8
# 2025/05/16 12:05:41 INFO mlflow.tracking.fluent: Experiment with name 'distillibert' does not exist. Creating a new experiment.
# 2025-05-16 12:05:41,622 - Experiment - INFO - MLflow experiment initialized with ID: 580058141891138922
# 2025-05-16 12:05:41,623 - Experiment - INFO - Model signature: model(mn=distillibert,ti=distilbert-base-uncased,mmn=loss,e=10,bs=16,ebs=16,lr=5e-05,ls=linear,wd=0.001,o=adamw_torch,esp=3,est=0.01)
# 2025-05-16 12:05:41,623 - Experiment - INFO - Dataset signature: dataset(dn=recovery,tp=0.7,vp=0.15);pipeline([distilli_bert__encoder(t=distilbert-base-uncased,t=true,p=max_length,tml=128,isiw=false)])
# ...

# %%
# %cd ../roberta
# %run training.ipynb

# %%
# %cd ../openai_gpt1
# %run training.ipynb

# %%
# %cd ../openai_gpt2
# %run training.ipynb
